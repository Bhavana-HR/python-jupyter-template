# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generating x values
x = np.linspace(0, 10, 100)
# Calculating y values as the square of x
y = x**2

# %%
# Creating the plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = x^2', color='blue')

# %%
# Customizing the plot
plt.title('Line Plot of y = x^2', fontsize=14)
plt.xlabel('x values', fontsize=12)
plt.ylabel('y values', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
# Out:
# /tmp/ipykernel_1854/174905602.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Displaying the plot
plt.show()
